# %%
from PIL import Image
import pandas as pd
data = pd.read_csv('pa_ll.csv')
path_list = data['Path'].tolist()
path = path_list[230]
print(path)
img=Image.open(path)
img.show()
# Out:
# /root/autodl-tmp/MIMIC/p18/p18117105/s57993220/87a754cf-05f4ddeb-9367b570-c4782a03-3722b64d.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=2140x1760>
